# %%
import json
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import sys
from collections import defaultdict
sys.path.append("/user/christoph.wald/u15287/insect_pest_detection/modules")
from modules_segmentation import *

# %%
# load the results of a training

with open("/user/christoph.wald/u15287/insect_pest_detection/2_5_self_training/metrics/train4/results.json", "r") as f:
    data = json.load(f)

#boxes in xyxy-format
print(data[0]["filename"])
box = data[0]["false_negatives"]["boxes"][1]
box
# Out:
# BRAIIM_0157.jpg
# [1359.0355224609375, 847.4884643554688, 1380.9310302734375, 889.4599609375]

# %%
# function to compute if a box is covered by the mask (with a threshold)

def compute_mask_coverage(mask, rectangles, threshold=0.8):
    """
    mask: np.ndarray (grayscale, same size as original image)
    rectangles: list of rectangles [(x_min, y_min, x_max, y_max), ...]
    Returns: list of (rect_idx, coverage_ratio, is_covered)
    """
    results = []
    for i, (x1, y1, x2, y2) in enumerate(rectangles):
        #x2 = x1 + w
        #y2 = y1 + h
        # Ensure bounds within image
        x1, y1 = max(0, int(x1)), max(0, int(y1))
        x2, y2 = min(mask.shape[1], int(x2)), min(mask.shape[0], int(y2))
        if x2 <= x1 or y2 <= y1:
            results.append((i, 0.0, False))
            continue

        # Extract mask region
        region = mask[y1:y2, x1:x2]

        # Count masked pixels (assuming 0=masked, 255=background)
        masked_pixels = np.sum(region == 0)
        total_pixels = region.size
        ratio = masked_pixels / total_pixels

        is_covered = ratio >= threshold
        results.append((i, ratio, is_covered))
    return results

# %%
#set image folder and load the mask

image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/02_images_rotated"
label_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/02_labels_rotated"

processed_mask = cv2.imread(
    "/user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/masks/06_generated_mask_fat_plus.jpg", 
    cv2.IMREAD_GRAYSCALE
)

gridcorners = np.load("/user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/masks/gridcorners.npy")
mask_h_line = np.load("/user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/masks/mask_h_line.npy")

image_files = os.listdir(image_folder)

with open("/user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/logs/rotated_files_test_set.txt", "r") as f:
    files_rotated = set(line.strip() for line in f)

# %%
#function to adapt the mask to an inidivual image

def get_mask(image_file):
    image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/02_images_rotated"
    #Load image file
    print(f"Loading {image_file}")
    image = cv2.imread(os.path.join(image_folder, image_file))

    #find YST contour of image
    imageYST = find_contour(image)

    #save cropped image
    x, y, w, h = cv2.boundingRect(imageYST)
    

    #find corners if possible, if not skip the image
    imagecorners = find_corners(image, imageYST)
    if len(imagecorners) == 0:
        print(f"No YST found for {image_file}")
        return None

    #find transformation
    H, _ = cv2.findHomography(gridcorners, imagecorners, cv2.RANSAC)

    #first transformation: 
    mask = cv2.warpPerspective(processed_mask, H, (image.shape[1], image.shape[0]))
    
    #transform midline of mask as above
    h_line_pts = mask_h_line.reshape(-1,1,2)
    h_line_pts_warped = cv2.perspectiveTransform(h_line_pts, H)
    x1w, y1w, x2w, y2w = h_line_pts_warped.reshape(-1).astype(np.int32)
    mask_h = (x1w, y1w, x2w, y2w)

    #second transformation: correct vertical misalignment
    image_h = get_h_mid(create_binary_mask(image))
    dy = get_midpoint(image_h)- get_midpoint(mask_h)
    print (dy)
    if abs(dy) > 500:
        print(f"Skipped vertical alignment, wrong horizontal line with offset {dy}")
    else:
        H, W = mask.shape[:2]
        M = np.float32([[1, 0, 0], [0, 1, dy]])  # translation matrix
        mask= cv2.warpAffine(mask, M, (W, H), borderValue=255)  # white background
    return mask[y:y+h, x:x+w]

# %%
#get the mask for an image and rotate it back if original image was rotated
f = data[1]["filename"]
mask = get_mask(f)
if f in files_rotated:
    print("Rotate mask")
    mask = cv2.rotate(mask, cv2.ROTATE_180)
rgb_image = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)
plt.axis("off")
plt.show()
# Out:
# Loading BRAIIM_0170.jpg
# using only simple binarization.
# using only simple binarization.
# 113.0
# Rotate mask

# %%
#compute which rectangles are overlapping with the mask
r = data[1]["false_negatives"]["boxes"]
overlaps = compute_mask_coverage(mask, r, threshold = 0.5)
overlaps
# Out:
# [(0, np.float64(0.8309535658232209), np.True_),
#  (1, np.float64(0.06650488770861473), np.False_),
#  (2, np.float64(0.5779560439560439), np.True_),
#  (3, np.float64(1.0), np.True_),
#  (4, np.float64(1.0), np.True_),
#  (5, np.float64(1.0), np.True_),
#  (6, np.float64(0.0), np.False_),
#  (7, np.float64(0.7418181818181818), np.True_),
#  (8, np.float64(0.5117797695262484), np.True_),
#  (9, np.float64(1.0), np.True_),
#  (10, np.float64(1.0), np.True_),
#  (11, np.float64(0.22002571520411443), np.False_),
#  (12, np.float64(0.0), np.False_),
#  (13, np.float64(1.0), np.True_),
#  (14, np.float64(0.8035714285714286), np.True_),
#  (15, np.float64(1.0), np.True_)]

# %%
#plot rectangles on image
#green: on mask, red: not (remains false negative)
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/images"
img_copy = cv2.imread(os.path.join(image_folder, f))
for i, box in enumerate(r):
    x1,y1,x2,y2 = map (int, box)
    if overlaps[i][2]:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=2)
    else:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=2)

img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %%
#same for masked image
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/03_images_masked"
img_copy = cv2.imread(os.path.join(image_folder, f))
if f in files_rotated:
    img_copy = cv2.rotate(img_copy, cv2.ROTATE_180)

for i, box in enumerate(r):
    x1,y1,x2,y2 = map (int, box)
    if overlaps[i][2]:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=5)
    else:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=5)

img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
cv2.imwrite("false_negatives_on_mask.jpg",img_copy)

plt.show()

# %%
#per class results

# Initialize per-class counters
stats = defaultdict(lambda: {"true": 0, "false": 0, "unchecked": 0})

for d in data:
    f = d["filename"]

    # Determine class from filename prefix
    if f.startswith("BRAIIM"):
        cls = "BRAIIM"
    elif f.startswith("LIRIBO"):
        cls = "LIRIBO"
    elif f.startswith("TRIAVA"):
        cls = "TRIAVA"
    else:
        cls = "UNKNOWN"

    r = d["false_negatives"]["boxes"]
    mask = get_mask(f)

    if mask is None:
        stats[cls]["unchecked"] += len(r)
        continue

    if f in files_rotated:
        print(f"Rotate mask for {f}")
        mask = cv2.rotate(mask, cv2.ROTATE_180)

    overlaps = compute_mask_coverage(mask, r)

    stats[cls]["true"] += sum(1 for _, _, val in overlaps if val)
    stats[cls]["false"] += sum(1 for _, _, val in overlaps if not val)

# Print per-class results
for cls, counts in stats.items():
    print(f"\nClass: {cls}")
    print(f"  True:      {counts['true']}")
    print(f"  False:     {counts['false']}")
    print(f"  Unchecked: {counts['unchecked']}")

# Optional: total summary
total_true = sum(c["true"] for c in stats.values())
total_false = sum(c["false"] for c in stats.values())
total_unchecked = sum(c["unchecked"] for c in stats.values())

print("\nOverall totals:")
print(f"  True:      {total_true}")
print(f"  False:     {total_false}")
print(f"  Unchecked: {total_unchecked}")
# Out:
# Loading BRAIIM_0157.jpg
# using only simple binarization.
# No YST found for BRAIIM_0157.jpg
# Loading BRAIIM_0170.jpg
# using only simple binarization.
# using only simple binarization.
# 113.0
# Rotate mask for BRAIIM_0170.jpg
# Loading BRAIIM_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for BRAIIM_0184.jpg
# Loading BRAIIM_0195.jpg
# using only simple binarization.
# No YST found for BRAIIM_0195.jpg
# Loading BRAIIM_0204.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for BRAIIM_0204.jpg
# Loading BRAIIM_0207.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for BRAIIM_0207.jpg
# Loading BRAIIM_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 30.0
# Rotate mask for BRAIIM_0223.jpg
# Loading BRAIIM_0286.jpg
# using only simple binarization.
# using only simple binarization.
# 33.5
# Rotate mask for BRAIIM_0286.jpg
# Loading BRAIIM_0288.jpg
# using only simple binarization.
# using only simple binarization.
# 54.0
# Rotate mask for BRAIIM_0288.jpg
# Loading BRAIIM_0302.jpg
# using only simple binarization.
# using only simple binarization.
# 48.5
# Rotate mask for BRAIIM_0302.jpg
# Loading BRAIIM_0319.jpg
# using only simple binarization.
# using only simple binarization.
# 31.5
# Rotate mask for BRAIIM_0319.jpg
# Loading BRAIIM_0384.jpg
# using only simple binarization.
# using only simple binarization.
# 74.0
# Rotate mask for BRAIIM_0384.jpg
# Loading BRAIIM_0403.jpg
# using only simple binarization.
# using only simple binarization.
# 79.5
# Rotate mask for BRAIIM_0403.jpg
# Loading BRAIIM_0416.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for BRAIIM_0416.jpg
# Loading BRAIIM_0456.jpg
# using only simple binarization.
# using only simple binarization.
# -1.5
# Rotate mask for BRAIIM_0456.jpg
# Loading BRAIIM_0469.jpg
# using only simple binarization.
# using only simple binarization.
# 18.5
# Rotate mask for BRAIIM_0469.jpg
# Loading BRAIIM_0477.jpg
# using only simple binarization.
# using only simple binarization.
# 5.5
# Rotate mask for BRAIIM_0477.jpg
# Loading BRAIIM_0498.jpg
# using only simple binarization.
# using only simple binarization.
# 9.0
# Rotate mask for BRAIIM_0498.jpg
# Loading BRAIIM_0612.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Rotate mask for BRAIIM_0612.jpg
# Loading BRAIIM_0693.jpg
# using only simple binarization.
# using only simple binarization.
# 27.5
# Rotate mask for BRAIIM_0693.jpg
# Loading BRAIIM_0720.jpg
# using only simple binarization.
# using only simple binarization.
# 17.5
# Rotate mask for BRAIIM_0720.jpg
# Loading BRAIIM_0735.jpg
# using only simple binarization.
# using only simple binarization.
# 15.5
# Rotate mask for BRAIIM_0735.jpg
# Loading BRAIIM_0740.jpg
# using only simple binarization.
# using only simple binarization.
# 56.0
# Rotate mask for BRAIIM_0740.jpg
# Loading BRAIIM_0754.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for BRAIIM_0754.jpg
# Loading BRAIIM_0779.jpg
# using only simple binarization.
# using only simple binarization.
# 79.0
# Rotate mask for BRAIIM_0779.jpg
# Loading BRAIIM_0781.jpg
# using only simple binarization.
# No YST found for BRAIIM_0781.jpg
# Loading BRAIIM_0796.jpg
# using only simple binarization.
# using only simple binarization.
# 3.5
# Rotate mask for BRAIIM_0796.jpg
# Loading BRAIIM_0821.jpg
# using only simple binarization.
# using only simple binarization.
# -0.5
# Rotate mask for BRAIIM_0821.jpg
# Loading BRAIIM_0824.jpg
# using only simple binarization.
# No YST found for BRAIIM_0824.jpg
# Loading BRAIIM_0825.jpg
# using only simple binarization.
# using only simple binarization.
# 3.0
# Rotate mask for BRAIIM_0825.jpg
# Loading BRAIIM_0913.jpg
# using only simple binarization.
# using only simple binarization.
# 37.0
# Rotate mask for BRAIIM_0913.jpg
# Loading BRAIIM_0944.jpg
# using only simple binarization.
# using only simple binarization.
# 37.0
# Rotate mask for BRAIIM_0944.jpg
# Loading BRAIIM_1044.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for BRAIIM_1044.jpg
# Loading BRAIIM_1047.jpg
# using only simple binarization.
# using only simple binarization.
# 43.5
# Rotate mask for BRAIIM_1047.jpg
# Loading BRAIIM_1059.jpg
# using only simple binarization.
# using only simple binarization.
# 44.0
# Rotate mask for BRAIIM_1059.jpg
# Loading BRAIIM_1128.jpg
# using only simple binarization.
# using only simple binarization.
# 47.0
# Rotate mask for BRAIIM_1128.jpg
# Loading BRAIIM_1134.jpg
# using only simple binarization.
# using only simple binarization.
# 58.0
# Rotate mask for BRAIIM_1134.jpg
# Loading BRAIIM_1161.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for BRAIIM_1161.jpg
# Loading BRAIIM_1183.jpg
# using only simple binarization.
# using only simple binarization.
# 63.0
# Rotate mask for BRAIIM_1183.jpg
# Loading BRAIIM_1211.jpg
# using only simple binarization.
# using only simple binarization.
# 40.0
# Rotate mask for BRAIIM_1211.jpg
# Loading LIRIBO_0003.jpg
# using only simple binarization.
# No YST found for LIRIBO_0003.jpg
# Loading LIRIBO_0008.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Loading LIRIBO_0011.jpg
# using only simple binarization.
# using only simple binarization.
# -4.5
# Rotate mask for LIRIBO_0011.jpg
# Loading LIRIBO_0017.jpg
# using only simple binarization.
# using only simple binarization.
# 74.0
# Loading LIRIBO_0021.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Loading LIRIBO_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 68.5
# Loading LIRIBO_0029.jpg
# using only simple binarization.
# using only simple binarization.
# 57.5
# Loading LIRIBO_0037.jpg
# using only simple binarization.
# using only simple binarization.
# 38.5
# Rotate mask for LIRIBO_0037.jpg
# Loading LIRIBO_0045.jpg
# using only simple binarization.
# using only simple binarization.
# 71.5
# Rotate mask for LIRIBO_0045.jpg
# Loading LIRIBO_0049.jpg
# using only simple binarization.
# using only simple binarization.
# -1187.0
# Skipped vertical alignment, wrong horizontal line with offset -1187.0
# Loading LIRIBO_0051.jpg
# using only simple binarization.
# using only simple binarization.
# 112.5
# Rotate mask for LIRIBO_0051.jpg
# Loading LIRIBO_0056.jpg
# using only simple binarization.
# using only simple binarization.
# 99.5
# Rotate mask for LIRIBO_0056.jpg
# Loading LIRIBO_0062.jpg
# using only simple binarization.
# using only simple binarization.
# 10.0
# Rotate mask for LIRIBO_0062.jpg
# Loading LIRIBO_0069.jpg
# using only simple binarization.
# using only simple binarization.
# 22.5
# Rotate mask for LIRIBO_0069.jpg
# Loading LIRIBO_0083.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Rotate mask for LIRIBO_0083.jpg
# Loading LIRIBO_0084.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for LIRIBO_0084.jpg
# Loading LIRIBO_0085.jpg
# using only simple binarization.
# using only simple binarization.
# 61.5
# Rotate mask for LIRIBO_0085.jpg
# Loading LIRIBO_0088.jpg
# using only simple binarization.
# using only simple binarization.
# 56.5
# Rotate mask for LIRIBO_0088.jpg
# Loading LIRIBO_0091.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Rotate mask for LIRIBO_0091.jpg
# Loading LIRIBO_0093.jpg
# using only simple binarization.
# using only simple binarization.
# 77.0
# Rotate mask for LIRIBO_0093.jpg
# Loading LIRIBO_0097.jpg
# using only simple binarization.
# using only simple binarization.
# 66.0
# Rotate mask for LIRIBO_0097.jpg
# Loading LIRIBO_0098.jpg
# using only simple binarization.
# using only simple binarization.
# 58.0
# Rotate mask for LIRIBO_0098.jpg
# Loading LIRIBO_0099.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for LIRIBO_0099.jpg
# Loading LIRIBO_0102.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for LIRIBO_0102.jpg
# Loading LIRIBO_0107.jpg
# using only simple binarization.
# using only simple binarization.
# 34.5
# Rotate mask for LIRIBO_0107.jpg
# Loading LIRIBO_0109.jpg
# using only simple binarization.
# using only simple binarization.
# 1254.0
# Skipped vertical alignment, wrong horizontal line with offset 1254.0
# Rotate mask for LIRIBO_0109.jpg
# Loading LIRIBO_0119.jpg
# using only simple binarization.
# using only simple binarization.
# 13.5
# Rotate mask for LIRIBO_0119.jpg
# Loading LIRIBO_0120.jpg
# using only simple binarization.
# using only simple binarization.
# 14.0
# Rotate mask for LIRIBO_0120.jpg
# Loading LIRIBO_0123.jpg
# using only simple binarization.
# using only simple binarization.
# 60.5
# Rotate mask for LIRIBO_0123.jpg
# Loading LIRIBO_0124.jpg
# using only simple binarization.
# using only simple binarization.
# 64.0
# Rotate mask for LIRIBO_0124.jpg
# Loading LIRIBO_0126.jpg
# using only simple binarization.
# using only simple binarization.
# 6.5
# Loading LIRIBO_0131.jpg
# using only simple binarization.
# using only simple binarization.
# 114.0
# Rotate mask for LIRIBO_0131.jpg
# Loading LIRIBO_0132.jpg
# using only simple binarization.
# using only simple binarization.
# 118.5
# Rotate mask for LIRIBO_0132.jpg
# Loading LIRIBO_0145.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for LIRIBO_0145.jpg
# Loading LIRIBO_0168.jpg
# using only simple binarization.
# using only simple binarization.
# 76.0
# Rotate mask for LIRIBO_0168.jpg
# Loading LIRIBO_0170.jpg
# using only simple binarization.
# using only simple binarization.
# -24.5
# Rotate mask for LIRIBO_0170.jpg
# Loading LIRIBO_0173.jpg
# using only simple binarization.
# using only simple binarization.
# -34.0
# Rotate mask for LIRIBO_0173.jpg
# Loading LIRIBO_0174.jpg
# using only simple binarization.
# using only simple binarization.
# -18.5
# Rotate mask for LIRIBO_0174.jpg
# Loading LIRIBO_0179.jpg
# using only simple binarization.
# using only simple binarization.
# 82.0
# Rotate mask for LIRIBO_0179.jpg
# Loading LIRIBO_0181.jpg
# using only simple binarization.
# using only simple binarization.
# 76.0
# Rotate mask for LIRIBO_0181.jpg
# Loading LIRIBO_0190.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for LIRIBO_0190.jpg
# Loading LIRIBO_0195.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0195.jpg
# Loading LIRIBO_0204.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for LIRIBO_0204.jpg
# Loading LIRIBO_0209.jpg
# using only simple binarization.
# using only simple binarization.
# 19.5
# Rotate mask for LIRIBO_0209.jpg
# Loading LIRIBO_0210.jpg
# using only simple binarization.
# using only simple binarization.
# -17.5
# Rotate mask for LIRIBO_0210.jpg
# Loading LIRIBO_0216.jpg
# using only simple binarization.
# using only simple binarization.
# -42.5
# Rotate mask for LIRIBO_0216.jpg
# Loading LIRIBO_0218.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.5
# Skipped vertical alignment, wrong horizontal line with offset 1163.5
# Rotate mask for LIRIBO_0218.jpg
# Loading LIRIBO_0228.jpg
# using only simple binarization.
# using only simple binarization.
# 1161.0
# Skipped vertical alignment, wrong horizontal line with offset 1161.0
# Rotate mask for LIRIBO_0228.jpg
# Loading LIRIBO_0232.jpg
# using only simple binarization.
# using only simple binarization.
# 20.5
# Rotate mask for LIRIBO_0232.jpg
# Loading LIRIBO_0242.jpg
# using only simple binarization.
# using only simple binarization.
# 17.5
# Rotate mask for LIRIBO_0242.jpg
# Loading LIRIBO_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 1191.5
# Skipped vertical alignment, wrong horizontal line with offset 1191.5
# Rotate mask for LIRIBO_0253.jpg
# Loading LIRIBO_0262.jpg
# using only simple binarization.
# using only simple binarization.
# 11.0
# Rotate mask for LIRIBO_0262.jpg
# Loading LIRIBO_0268.jpg
# using only simple binarization.
# using only simple binarization.
# -19.0
# Rotate mask for LIRIBO_0268.jpg
# Loading LIRIBO_0269.jpg
# using only simple binarization.
# using only simple binarization.
# -44.0
# Rotate mask for LIRIBO_0269.jpg
# Loading LIRIBO_0273.jpg
# using only simple binarization.
# using only simple binarization.
# 16.0
# Rotate mask for LIRIBO_0273.jpg
# Loading LIRIBO_0274.jpg
# using only simple binarization.
# using only simple binarization.
# 21.5
# Rotate mask for LIRIBO_0274.jpg
# Loading LIRIBO_0275.jpg
# using only simple binarization.
# using only simple binarization.
# -22.0
# Rotate mask for LIRIBO_0275.jpg
# Loading LIRIBO_0277.jpg
# using only simple binarization.
# using only simple binarization.
# -37.0
# Rotate mask for LIRIBO_0277.jpg
# Loading LIRIBO_0283.jpg
# using only simple binarization.
# using only simple binarization.
# -22.0
# Rotate mask for LIRIBO_0283.jpg
# Loading LIRIBO_0284.jpg
# using only simple binarization.
# using only simple binarization.
# 13.5
# Rotate mask for LIRIBO_0284.jpg
# Loading LIRIBO_0290.jpg
# using only simple binarization.
# No YST found for LIRIBO_0290.jpg
# Loading LIRIBO_0297.jpg
# using only simple binarization.
# using only simple binarization.
# -68.0
# Rotate mask for LIRIBO_0297.jpg
# Loading LIRIBO_0311.jpg
# using only simple binarization.
# using only simple binarization.
# 0.0
# Rotate mask for LIRIBO_0311.jpg
# Loading LIRIBO_0312.jpg
# using only simple binarization.
# using only simple binarization.
# 18.5
# Rotate mask for LIRIBO_0312.jpg
# Loading LIRIBO_0322.jpg
# using only simple binarization.
# using only simple binarization.
# 20.5
# Rotate mask for LIRIBO_0322.jpg
# Loading LIRIBO_0323.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0323.jpg
# Loading LIRIBO_0329.jpg
# using only simple binarization.
# using only simple binarization.
# 1187.5
# Skipped vertical alignment, wrong horizontal line with offset 1187.5
# Rotate mask for LIRIBO_0329.jpg
# Loading LIRIBO_0337.jpg
# using only simple binarization.
# using only simple binarization.
# -29.0
# Rotate mask for LIRIBO_0337.jpg
# Loading LIRIBO_0340.jpg
# using only simple binarization.
# using only simple binarization.
# 1241.5
# Skipped vertical alignment, wrong horizontal line with offset 1241.5
# Rotate mask for LIRIBO_0340.jpg
# Loading LIRIBO_0346.jpg
# using only simple binarization.
# using only simple binarization.
# -27.0
# Rotate mask for LIRIBO_0346.jpg
# Loading LIRIBO_0349.jpg
# using only simple binarization.
# No YST found for LIRIBO_0349.jpg
# Loading LIRIBO_0351.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0351.jpg
# Loading LIRIBO_0354.jpg
# using only simple binarization.
# using only simple binarization.
# -30.0
# Rotate mask for LIRIBO_0354.jpg
# Loading LIRIBO_0376.jpg
# using only simple binarization.
# using only simple binarization.
# 99.0
# Rotate mask for LIRIBO_0376.jpg
# Loading LIRIBO_0377.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0377.jpg
# Loading LIRIBO_0380.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for LIRIBO_0380.jpg
# Loading LIRIBO_0397.jpg
# using only simple binarization.
# using only simple binarization.
# 98.5
# Rotate mask for LIRIBO_0397.jpg
# Loading LIRIBO_0401.jpg
# using only simple binarization.
# using only simple binarization.
# 102.5
# Rotate mask for LIRIBO_0401.jpg
# Loading LIRIBO_0413.jpg
# using only simple binarization.
# using only simple binarization.
# -30.0
# Rotate mask for LIRIBO_0413.jpg
# Loading LIRIBO_0416.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0416.jpg
# Loading LIRIBO_0430.jpg
# using only simple binarization.
# using only simple binarization.
# 113.5
# Rotate mask for LIRIBO_0430.jpg
# Loading LIRIBO_0434.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0434.jpg
# Loading LIRIBO_0440.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for LIRIBO_0440.jpg
# Loading LIRIBO_0447.jpg
# using only simple binarization.
# using only simple binarization.
# 82.0
# Rotate mask for LIRIBO_0447.jpg
# Loading LIRIBO_0457.jpg
# using only simple binarization.
# using only simple binarization.
# -17.0
# Rotate mask for LIRIBO_0457.jpg
# Loading LIRIBO_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 73.5
# Rotate mask for LIRIBO_0463.jpg
# Loading LIRIBO_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Rotate mask for LIRIBO_0467.jpg
# Loading LIRIBO_0471.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for LIRIBO_0471.jpg
# Loading LIRIBO_0488.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Rotate mask for LIRIBO_0488.jpg
# Loading LIRIBO_0489.jpg
# using only simple binarization.
# using only simple binarization.
# 68.5
# Rotate mask for LIRIBO_0489.jpg
# Loading LIRIBO_0490.jpg
# using only simple binarization.
# using only simple binarization.
# 85.5
# Rotate mask for LIRIBO_0490.jpg
# Loading LIRIBO_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1195.5
# Skipped vertical alignment, wrong horizontal line with offset 1195.5
# Rotate mask for LIRIBO_0500.jpg
# Loading LIRIBO_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 86.0
# Rotate mask for LIRIBO_0501.jpg
# Loading LIRIBO_0509.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for LIRIBO_0509.jpg
# Loading LIRIBO_0517.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Rotate mask for LIRIBO_0517.jpg
# Loading LIRIBO_0519.jpg
# using only simple binarization.
# using only simple binarization.
# 105.0
# Rotate mask for LIRIBO_0519.jpg
# Loading LIRIBO_0525.jpg
# using only simple binarization.
# using only simple binarization.
# 1220.0
# Skipped vertical alignment, wrong horizontal line with offset 1220.0
# Rotate mask for LIRIBO_0525.jpg
# Loading LIRIBO_0530.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0530.jpg
# Loading LIRIBO_0533.jpg
# using only simple binarization.
# No YST found for LIRIBO_0533.jpg
# Loading LIRIBO_0534.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0534.jpg
# Loading LIRIBO_0539.jpg
# using only simple binarization.
# No YST found for LIRIBO_0539.jpg
# Loading LIRIBO_0543.jpg
# using only simple binarization.
# No YST found for LIRIBO_0543.jpg
# Loading LIRIBO_0544.jpg
# using only simple binarization.
# No YST found for LIRIBO_0544.jpg
# Loading LIRIBO_0546.jpg
# using only simple binarization.
# No YST found for LIRIBO_0546.jpg
# Loading LIRIBO_0547.jpg
# using only simple binarization.
# No YST found for LIRIBO_0547.jpg
# Loading LIRIBO_0553.jpg
# using only simple binarization.
# No YST found for LIRIBO_0553.jpg
# Loading LIRIBO_0557.jpg
# using only simple binarization.
# No YST found for LIRIBO_0557.jpg
# Loading LIRIBO_0562.jpg
# using only simple binarization.
# No YST found for LIRIBO_0562.jpg
# Loading LIRIBO_0569.jpg
# using only simple binarization.
# No YST found for LIRIBO_0569.jpg
# Loading LIRIBO_0571.jpg
# using only simple binarization.
# using only simple binarization.
# 104.5
# Rotate mask for LIRIBO_0571.jpg
# Loading LIRIBO_0574.jpg
# using only simple binarization.
# No YST found for LIRIBO_0574.jpg
# Loading LIRIBO_0577.jpg
# using only simple binarization.
# using only simple binarization.
# 120.0
# Rotate mask for LIRIBO_0577.jpg
# Loading LIRIBO_0587.jpg
# using only simple binarization.
# using only simple binarization.
# 108.5
# Rotate mask for LIRIBO_0587.jpg
# Loading LIRIBO_0588.jpg
# using only simple binarization.
# No YST found for LIRIBO_0588.jpg
# Loading LIRIBO_0589.jpg
# using only simple binarization.
# using only simple binarization.
# 100.0
# Rotate mask for LIRIBO_0589.jpg
# Loading LIRIBO_0600.jpg
# using only simple binarization.
# No YST found for LIRIBO_0600.jpg
# Loading LIRIBO_0606.jpg
# using only simple binarization.
# using only simple binarization.
# 112.0
# Rotate mask for LIRIBO_0606.jpg
# Loading LIRIBO_0613.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for LIRIBO_0613.jpg
# Loading LIRIBO_0619.jpg
# using only simple binarization.
# using only simple binarization.
# 99.5
# Rotate mask for LIRIBO_0619.jpg
# Loading LIRIBO_0621.jpg
# using only simple binarization.
# using only simple binarization.
# 100.0
# Rotate mask for LIRIBO_0621.jpg
# Loading LIRIBO_0634.jpg
# using only simple binarization.
# using only simple binarization.
# 1207.0
# Skipped vertical alignment, wrong horizontal line with offset 1207.0
# Rotate mask for LIRIBO_0634.jpg
# Loading LIRIBO_0635.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for LIRIBO_0635.jpg
# Loading LIRIBO_0638.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0638.jpg
# Loading LIRIBO_0640.jpg
# using only simple binarization.
# using only simple binarization.
# 88.5
# Rotate mask for LIRIBO_0640.jpg
# Loading LIRIBO_0643.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for LIRIBO_0643.jpg
# Loading LIRIBO_0649.jpg
# using only simple binarization.
# using only simple binarization.
# 78.0
# Rotate mask for LIRIBO_0649.jpg
# Loading LIRIBO_0654.jpg
# using only simple binarization.
# using only simple binarization.
# 79.5
# Rotate mask for LIRIBO_0654.jpg
# Loading LIRIBO_0658.jpg
# using only simple binarization.
# using only simple binarization.
# 84.5
# Rotate mask for LIRIBO_0658.jpg
# Loading LIRIBO_0659.jpg
# using only simple binarization.
# using only simple binarization.
# 89.0
# Rotate mask for LIRIBO_0659.jpg
# Loading LIRIBO_0669.jpg
# using only simple binarization.
# using only simple binarization.
# 109.5
# Rotate mask for LIRIBO_0669.jpg
# Loading LIRIBO_0673.jpg
# using only simple binarization.
# using only simple binarization.
# 107.0
# Rotate mask for LIRIBO_0673.jpg
# Loading TRIAVA_0007.jpg
# using only simple binarization.
# using only simple binarization.
# 2.5
# Rotate mask for TRIAVA_0007.jpg
# Loading TRIAVA_0019.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Loading TRIAVA_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 62.5
# Rotate mask for TRIAVA_0028.jpg
# Loading TRIAVA_0140.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for TRIAVA_0140.jpg
# Loading TRIAVA_0180.jpg
# using only simple binarization.
# using only simple binarization.
# 22.0
# Rotate mask for TRIAVA_0180.jpg
# Loading TRIAVA_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 31.0
# Rotate mask for TRIAVA_0184.jpg
# Loading TRIAVA_0185.jpg
# using only simple binarization.
# using only simple binarization.
# 16.5
# Rotate mask for TRIAVA_0185.jpg
# Loading TRIAVA_0187.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for TRIAVA_0187.jpg
# Loading TRIAVA_0188.jpg
# using only simple binarization.
# using only simple binarization.
# 19.0
# Rotate mask for TRIAVA_0188.jpg
# Loading TRIAVA_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 69.0
# Rotate mask for TRIAVA_0223.jpg
# Loading TRIAVA_0237.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for TRIAVA_0237.jpg
# Loading TRIAVA_0243.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for TRIAVA_0243.jpg
# Loading TRIAVA_0249.jpg
# using only simple binarization.
# using only simple binarization.
# 110.0
# Rotate mask for TRIAVA_0249.jpg
# Loading TRIAVA_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 110.5
# Rotate mask for TRIAVA_0253.jpg
# Loading TRIAVA_0269.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for TRIAVA_0269.jpg
# Loading TRIAVA_0276.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for TRIAVA_0276.jpg
# Loading TRIAVA_0302.jpg
# using only simple binarization.
# No YST found for TRIAVA_0302.jpg
# Loading TRIAVA_0304.jpg
# using only simple binarization.
# No YST found for TRIAVA_0304.jpg
# Loading TRIAVA_0318.jpg
# using only simple binarization.
# using only simple binarization.
# 103.0
# Rotate mask for TRIAVA_0318.jpg
# Loading TRIAVA_0324.jpg
# using only simple binarization.
# using only simple binarization.
# 119.5
# Rotate mask for TRIAVA_0324.jpg
# Loading TRIAVA_0325.jpg
# using only simple binarization.
# using only simple binarization.
# 111.0
# Rotate mask for TRIAVA_0325.jpg
# Loading TRIAVA_0335.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for TRIAVA_0335.jpg
# Loading TRIAVA_0354.jpg
# using only simple binarization.
# using only simple binarization.
# 14.5
# Rotate mask for TRIAVA_0354.jpg
# Loading TRIAVA_0357.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for TRIAVA_0357.jpg
# Loading TRIAVA_0358.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.0
# Skipped vertical alignment, wrong horizontal line with offset 1163.0
# Rotate mask for TRIAVA_0358.jpg
# Loading TRIAVA_0371.jpg
# using only simple binarization.
# using only simple binarization.
# 21.0
# Rotate mask for TRIAVA_0371.jpg
# Loading TRIAVA_0379.jpg
# using only simple binarization.
# using only simple binarization.
# -9.0
# Rotate mask for TRIAVA_0379.jpg
# Loading TRIAVA_0389.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for TRIAVA_0389.jpg
# Loading TRIAVA_0456.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for TRIAVA_0456.jpg
# Loading TRIAVA_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 1250.5
# Skipped vertical alignment, wrong horizontal line with offset 1250.5
# Rotate mask for TRIAVA_0463.jpg
# Loading TRIAVA_0465.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for TRIAVA_0465.jpg
# Loading TRIAVA_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 1225.5
# Skipped vertical alignment, wrong horizontal line with offset 1225.5
# Rotate mask for TRIAVA_0467.jpg
# Loading TRIAVA_0485.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for TRIAVA_0485.jpg
# Loading TRIAVA_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1197.5
# Skipped vertical alignment, wrong horizontal line with offset 1197.5
# Rotate mask for TRIAVA_0500.jpg
# Loading TRIAVA_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 1189.0
# Skipped vertical alignment, wrong horizontal line with offset 1189.0
# Rotate mask for TRIAVA_0501.jpg
# Loading TRIAVA_0504.jpg
# using only simple binarization.
# using only simple binarization.
# -24.0
# Rotate mask for TRIAVA_0504.jpg
# Loading TRIAVA_0590.jpg
# using only simple binarization.
# using only simple binarization.
# 75.0
# Rotate mask for TRIAVA_0590.jpg
# Loading TRIAVA_0591.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for TRIAVA_0591.jpg
# Loading TRIAVA_0626.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for TRIAVA_0626.jpg
# Loading TRIAVA_0628.jpg
# using only simple binarization.
# using only simple binarization.
# -15.5
# Rotate mask for TRIAVA_0628.jpg
#
# Class: BRAIIM
#   True:      185
#   False:     189
#   Unchecked: 78
#
# Class: LIRIBO
#   True:      105
#   False:     116
#   Unchecked: 28
#
# Class: TRIAVA
#   True:      709
#   False:     927
#   Unchecked: 59
#
# Overall totals:
#   True:      999
#   False:     1232
#   Unchecked: 165

# %%
stats
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'BRAIIM': {'true': 185, 'false': 189, 'unchecked': 78},
#              'LIRIBO': {'true': 105, 'false': 116, 'unchecked': 28},
#              'TRIAVA': {'true': 709, 'false': 927, 'unchecked': 59}})

# %%
#load metrics

with open("/user/christoph.wald/u15287/insect_pest_detection/2_5_self_training/metrics/train4/metrics.json", "r") as f:
    metrics = json.load(f)
metrics

import pandas as pd
# Combine summary and per-class metrics
rows = {'summary': metrics['summary']}
rows.update(metrics['per_class'])

# Create DataFrame
df = pd.DataFrame(rows).T

# Compute F1 for each row
df['f1'] = 2 * df['precision'] * df['recall'] / (df['precision'] + df['recall'])

df
# Out:
#              TP     FP      FN  precision    recall        f1
# summary  3064.0  589.0  2396.0   0.838763  0.561172  0.672446
# 0        1127.0  321.0   452.0   0.778315  0.713743  0.744632
# 1        1010.0  179.0   249.0   0.849453  0.802224  0.825163
# 3         927.0   89.0  1695.0   0.912402  0.353547  0.509621

# %%
def add_row_fn(df, row_name, mask_value):
    base = df.loc[row_name].copy()

    # Recalculate derived metrics
    tp, fp, fn = base['TP'], base['FP'], base['FN']-mask_value
    precision = tp / (tp + fp) if tp + fp > 0 else 0

    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    print(recall)

    # Create new row
    new_row = base.copy()
    print(new_row)
    new_row["FN"] = fn
    new_row['precision'] = precision
    new_row['recall'] = recall
    new_row['f1'] = f1
    return new_row

#subtract the false negatives correlated to masking
df.loc["summary_fn_masked"] = add_row_fn(df, "summary", 185+105+709)
df.loc["0_fn_masked"] = add_row_fn(df, "0", 185)
df.loc["1_fn_masked"] = add_row_fn(df, "1", 105)
df.loc["3_fn_masked"] = add_row_fn(df, "3", 709)
df
# Out:
# 0.6868415153553015
# TP           3064.000000
# FP            589.000000
# FN           2396.000000
# precision       0.838763
# recall          0.561172
# f1              0.672446
# Name: summary, dtype: float64
# 0.8084648493543759
# TP           1127.000000
# FP            321.000000
# FN            452.000000
# precision       0.778315
# recall          0.713743
# f1              0.744632
# Name: 0, dtype: float64
# 0.8752166377816292
# TP           1010.000000
# FP            179.000000
# FN            249.000000
# precision       0.849453
# recall          0.802224
# f1              0.825163
# Name: 1, dtype: float64
# 0.48457919498170415
# TP            927.000000
# FP             89.000000
# FN           1695.000000
# precision       0.912402
# recall          0.353547
# f1              0.509621
# Name: 3, dtype: float64
#                        TP     FP      FN  precision    recall        f1
# summary            3064.0  589.0  2396.0   0.838763  0.561172  0.672446
# 0                  1127.0  321.0   452.0   0.778315  0.713743  0.744632
# 1                  1010.0  179.0   249.0   0.849453  0.802224  0.825163
# 3                   927.0   89.0  1695.0   0.912402  0.353547  0.509621
# summary_fn_masked  3064.0  589.0  1397.0   0.838763  0.686842  0.755238
# 0_fn_masked        1127.0  321.0   267.0   0.778315  0.808465  0.793103
# 1_fn_masked        1010.0  179.0   144.0   0.849453  0.875217  0.862143
# 3_fn_masked         927.0   89.0   986.0   0.912402  0.484579  0.632981

# %%
#get the mask for an image and rotate it back if original image was rotated
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/02_images_rotated"
i = 10
f = data[i]["filename"]
mask = get_mask(f)
if f in files_rotated:
    print("Rotate mask")
    mask = cv2.rotate(mask, cv2.ROTATE_180)
rgb_image = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)
plt.axis("off")
plt.show()
#compute which rectangles are overlapping with the mask
r = data[i]["false_positives"]["boxes"]
overlaps = compute_mask_coverage(mask, r, threshold = 1.0)
#plot rectangles on image
#green: on mask, red: not (remains false negative)
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/images"
img_copy = cv2.imread(os.path.join(image_folder, f))
for i, box in enumerate(r):
    x1,y1,x2,y2 = map (int, box)
    if overlaps[i][2]:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=2)
    else:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=2)

img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()
#same for masked image
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/03_images_masked"
img_copy = cv2.imread(os.path.join(image_folder, f))
if f in files_rotated:
    img_copy = cv2.rotate(img_copy, cv2.ROTATE_180)

for i, box in enumerate(r):
    x1,y1,x2,y2 = map (int, box)
    if overlaps[i][2]:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=5)
    else:
        cv2.rectangle(img_copy, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=5)

cv2.imwrite("false_positives_on_mask.jpg",img_copy)
img_rgb = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()
print(overlaps)
# Out:
# Loading BRAIIM_0319.jpg
# using only simple binarization.
# using only simple binarization.
# 31.5
# Rotate mask
# [(0, np.float64(0.0), np.False_), (1, np.float64(0.0), np.False_), (2, np.float64(1.0), np.True_), (3, np.float64(0.5343207354443309), np.False_)]

# %%
#per class results
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/02_images_rotated"

# Initialize per-class counters
stats = defaultdict(lambda: {"true": 0, "false": 0, "unchecked": 0})

for d in data:
    f = d["filename"]

    # Determine class from filename prefix
    if f.startswith("BRAIIM"):
        cls = "BRAIIM"
    elif f.startswith("LIRIBO"):
        cls = "LIRIBO"
    elif f.startswith("TRIAVA"):
        cls = "TRIAVA"
    else:
        cls = "UNKNOWN"

    r = d["false_positives"]["boxes"]
    mask = get_mask(f)

    if mask is None:
        stats[cls]["unchecked"] += len(r)
        continue

    if f in files_rotated:
        print(f"Rotate mask for {f}")
        mask = cv2.rotate(mask, cv2.ROTATE_180)

    overlaps = compute_mask_coverage(mask, r, threshold = 1.0)

    stats[cls]["true"] += sum(1 for _, _, val in overlaps if val)
    stats[cls]["false"] += sum(1 for _, _, val in overlaps if not val)

# Print per-class results
for cls, counts in stats.items():
    print(f"\nClass: {cls}")
    print(f"  True:      {counts['true']}")
    print(f"  False:     {counts['false']}")
    print(f"  Unchecked: {counts['unchecked']}")

# Optional: total summary
total_true = sum(c["true"] for c in stats.values())
total_false = sum(c["false"] for c in stats.values())
total_unchecked = sum(c["unchecked"] for c in stats.values())

print("\nOverall totals:")
print(f"  True:      {total_true}")
print(f"  False:     {total_false}")
print(f"  Unchecked: {total_unchecked}")
# Out:
# Loading BRAIIM_0157.jpg
# using only simple binarization.
# No YST found for BRAIIM_0157.jpg
# Loading BRAIIM_0170.jpg
# using only simple binarization.
# using only simple binarization.
# 113.0
# Rotate mask for BRAIIM_0170.jpg
# Loading BRAIIM_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for BRAIIM_0184.jpg
# Loading BRAIIM_0195.jpg
# using only simple binarization.
# No YST found for BRAIIM_0195.jpg
# Loading BRAIIM_0204.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for BRAIIM_0204.jpg
# Loading BRAIIM_0207.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for BRAIIM_0207.jpg
# Loading BRAIIM_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 30.0
# Rotate mask for BRAIIM_0223.jpg
# Loading BRAIIM_0286.jpg
# using only simple binarization.
# using only simple binarization.
# 33.5
# Rotate mask for BRAIIM_0286.jpg
# Loading BRAIIM_0288.jpg
# using only simple binarization.
# using only simple binarization.
# 54.0
# Rotate mask for BRAIIM_0288.jpg
# Loading BRAIIM_0302.jpg
# using only simple binarization.
# using only simple binarization.
# 48.5
# Rotate mask for BRAIIM_0302.jpg
# Loading BRAIIM_0319.jpg
# using only simple binarization.
# using only simple binarization.
# 31.5
# Rotate mask for BRAIIM_0319.jpg
# Loading BRAIIM_0384.jpg
# using only simple binarization.
# using only simple binarization.
# 74.0
# Rotate mask for BRAIIM_0384.jpg
# Loading BRAIIM_0403.jpg
# using only simple binarization.
# using only simple binarization.
# 79.5
# Rotate mask for BRAIIM_0403.jpg
# Loading BRAIIM_0416.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for BRAIIM_0416.jpg
# Loading BRAIIM_0456.jpg
# using only simple binarization.
# using only simple binarization.
# -1.5
# Rotate mask for BRAIIM_0456.jpg
# Loading BRAIIM_0469.jpg
# using only simple binarization.
# using only simple binarization.
# 18.5
# Rotate mask for BRAIIM_0469.jpg
# Loading BRAIIM_0477.jpg
# using only simple binarization.
# using only simple binarization.
# 5.5
# Rotate mask for BRAIIM_0477.jpg
# Loading BRAIIM_0498.jpg
# using only simple binarization.
# using only simple binarization.
# 9.0
# Rotate mask for BRAIIM_0498.jpg
# Loading BRAIIM_0612.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Rotate mask for BRAIIM_0612.jpg
# Loading BRAIIM_0693.jpg
# using only simple binarization.
# using only simple binarization.
# 27.5
# Rotate mask for BRAIIM_0693.jpg
# Loading BRAIIM_0720.jpg
# using only simple binarization.
# using only simple binarization.
# 17.5
# Rotate mask for BRAIIM_0720.jpg
# Loading BRAIIM_0735.jpg
# using only simple binarization.
# using only simple binarization.
# 15.5
# Rotate mask for BRAIIM_0735.jpg
# Loading BRAIIM_0740.jpg
# using only simple binarization.
# using only simple binarization.
# 56.0
# Rotate mask for BRAIIM_0740.jpg
# Loading BRAIIM_0754.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for BRAIIM_0754.jpg
# Loading BRAIIM_0779.jpg
# using only simple binarization.
# using only simple binarization.
# 79.0
# Rotate mask for BRAIIM_0779.jpg
# Loading BRAIIM_0781.jpg
# using only simple binarization.
# No YST found for BRAIIM_0781.jpg
# Loading BRAIIM_0796.jpg
# using only simple binarization.
# using only simple binarization.
# 3.5
# Rotate mask for BRAIIM_0796.jpg
# Loading BRAIIM_0821.jpg
# using only simple binarization.
# using only simple binarization.
# -0.5
# Rotate mask for BRAIIM_0821.jpg
# Loading BRAIIM_0824.jpg
# using only simple binarization.
# No YST found for BRAIIM_0824.jpg
# Loading BRAIIM_0825.jpg
# using only simple binarization.
# using only simple binarization.
# 3.0
# Rotate mask for BRAIIM_0825.jpg
# Loading BRAIIM_0913.jpg
# using only simple binarization.
# using only simple binarization.
# 37.0
# Rotate mask for BRAIIM_0913.jpg
# Loading BRAIIM_0944.jpg
# using only simple binarization.
# using only simple binarization.
# 37.0
# Rotate mask for BRAIIM_0944.jpg
# Loading BRAIIM_1044.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for BRAIIM_1044.jpg
# Loading BRAIIM_1047.jpg
# using only simple binarization.
# using only simple binarization.
# 43.5
# Rotate mask for BRAIIM_1047.jpg
# Loading BRAIIM_1059.jpg
# using only simple binarization.
# using only simple binarization.
# 44.0
# Rotate mask for BRAIIM_1059.jpg
# Loading BRAIIM_1128.jpg
# using only simple binarization.
# using only simple binarization.
# 47.0
# Rotate mask for BRAIIM_1128.jpg
# Loading BRAIIM_1134.jpg
# using only simple binarization.
# using only simple binarization.
# 58.0
# Rotate mask for BRAIIM_1134.jpg
# Loading BRAIIM_1161.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for BRAIIM_1161.jpg
# Loading BRAIIM_1183.jpg
# using only simple binarization.
# using only simple binarization.
# 63.0
# Rotate mask for BRAIIM_1183.jpg
# Loading BRAIIM_1211.jpg
# using only simple binarization.
# using only simple binarization.
# 40.0
# Rotate mask for BRAIIM_1211.jpg
# Loading LIRIBO_0003.jpg
# using only simple binarization.
# No YST found for LIRIBO_0003.jpg
# Loading LIRIBO_0008.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Loading LIRIBO_0011.jpg
# using only simple binarization.
# using only simple binarization.
# -4.5
# Rotate mask for LIRIBO_0011.jpg
# Loading LIRIBO_0017.jpg
# using only simple binarization.
# using only simple binarization.
# 74.0
# Loading LIRIBO_0021.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Loading LIRIBO_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 68.5
# Loading LIRIBO_0029.jpg
# using only simple binarization.
# using only simple binarization.
# 57.5
# Loading LIRIBO_0037.jpg
# using only simple binarization.
# using only simple binarization.
# 38.5
# Rotate mask for LIRIBO_0037.jpg
# Loading LIRIBO_0045.jpg
# using only simple binarization.
# using only simple binarization.
# 71.5
# Rotate mask for LIRIBO_0045.jpg
# Loading LIRIBO_0049.jpg
# using only simple binarization.
# using only simple binarization.
# -1187.0
# Skipped vertical alignment, wrong horizontal line with offset -1187.0
# Loading LIRIBO_0051.jpg
# using only simple binarization.
# using only simple binarization.
# 112.5
# Rotate mask for LIRIBO_0051.jpg
# Loading LIRIBO_0056.jpg
# using only simple binarization.
# using only simple binarization.
# 99.5
# Rotate mask for LIRIBO_0056.jpg
# Loading LIRIBO_0062.jpg
# using only simple binarization.
# using only simple binarization.
# 10.0
# Rotate mask for LIRIBO_0062.jpg
# Loading LIRIBO_0069.jpg
# using only simple binarization.
# using only simple binarization.
# 22.5
# Rotate mask for LIRIBO_0069.jpg
# Loading LIRIBO_0083.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Rotate mask for LIRIBO_0083.jpg
# Loading LIRIBO_0084.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for LIRIBO_0084.jpg
# Loading LIRIBO_0085.jpg
# using only simple binarization.
# using only simple binarization.
# 61.5
# Rotate mask for LIRIBO_0085.jpg
# Loading LIRIBO_0088.jpg
# using only simple binarization.
# using only simple binarization.
# 56.5
# Rotate mask for LIRIBO_0088.jpg
# Loading LIRIBO_0091.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Rotate mask for LIRIBO_0091.jpg
# Loading LIRIBO_0093.jpg
# using only simple binarization.
# using only simple binarization.
# 77.0
# Rotate mask for LIRIBO_0093.jpg
# Loading LIRIBO_0097.jpg
# using only simple binarization.
# using only simple binarization.
# 66.0
# Rotate mask for LIRIBO_0097.jpg
# Loading LIRIBO_0098.jpg
# using only simple binarization.
# using only simple binarization.
# 58.0
# Rotate mask for LIRIBO_0098.jpg
# Loading LIRIBO_0099.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for LIRIBO_0099.jpg
# Loading LIRIBO_0102.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for LIRIBO_0102.jpg
# Loading LIRIBO_0107.jpg
# using only simple binarization.
# using only simple binarization.
# 34.5
# Rotate mask for LIRIBO_0107.jpg
# Loading LIRIBO_0109.jpg
# using only simple binarization.
# using only simple binarization.
# 1254.0
# Skipped vertical alignment, wrong horizontal line with offset 1254.0
# Rotate mask for LIRIBO_0109.jpg
# Loading LIRIBO_0119.jpg
# using only simple binarization.
# using only simple binarization.
# 13.5
# Rotate mask for LIRIBO_0119.jpg
# Loading LIRIBO_0120.jpg
# using only simple binarization.
# using only simple binarization.
# 14.0
# Rotate mask for LIRIBO_0120.jpg
# Loading LIRIBO_0123.jpg
# using only simple binarization.
# using only simple binarization.
# 60.5
# Rotate mask for LIRIBO_0123.jpg
# Loading LIRIBO_0124.jpg
# using only simple binarization.
# using only simple binarization.
# 64.0
# Rotate mask for LIRIBO_0124.jpg
# Loading LIRIBO_0126.jpg
# using only simple binarization.
# using only simple binarization.
# 6.5
# Loading LIRIBO_0131.jpg
# using only simple binarization.
# using only simple binarization.
# 114.0
# Rotate mask for LIRIBO_0131.jpg
# Loading LIRIBO_0132.jpg
# using only simple binarization.
# using only simple binarization.
# 118.5
# Rotate mask for LIRIBO_0132.jpg
# Loading LIRIBO_0145.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for LIRIBO_0145.jpg
# Loading LIRIBO_0168.jpg
# using only simple binarization.
# using only simple binarization.
# 76.0
# Rotate mask for LIRIBO_0168.jpg
# Loading LIRIBO_0170.jpg
# using only simple binarization.
# using only simple binarization.
# -24.5
# Rotate mask for LIRIBO_0170.jpg
# Loading LIRIBO_0173.jpg
# using only simple binarization.
# using only simple binarization.
# -34.0
# Rotate mask for LIRIBO_0173.jpg
# Loading LIRIBO_0174.jpg
# using only simple binarization.
# using only simple binarization.
# -18.5
# Rotate mask for LIRIBO_0174.jpg
# Loading LIRIBO_0179.jpg
# using only simple binarization.
# using only simple binarization.
# 82.0
# Rotate mask for LIRIBO_0179.jpg
# Loading LIRIBO_0181.jpg
# using only simple binarization.
# using only simple binarization.
# 76.0
# Rotate mask for LIRIBO_0181.jpg
# Loading LIRIBO_0190.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for LIRIBO_0190.jpg
# Loading LIRIBO_0195.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0195.jpg
# Loading LIRIBO_0204.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for LIRIBO_0204.jpg
# Loading LIRIBO_0209.jpg
# using only simple binarization.
# using only simple binarization.
# 19.5
# Rotate mask for LIRIBO_0209.jpg
# Loading LIRIBO_0210.jpg
# using only simple binarization.
# using only simple binarization.
# -17.5
# Rotate mask for LIRIBO_0210.jpg
# Loading LIRIBO_0216.jpg
# using only simple binarization.
# using only simple binarization.
# -42.5
# Rotate mask for LIRIBO_0216.jpg
# Loading LIRIBO_0218.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.5
# Skipped vertical alignment, wrong horizontal line with offset 1163.5
# Rotate mask for LIRIBO_0218.jpg
# Loading LIRIBO_0228.jpg
# using only simple binarization.
# using only simple binarization.
# 1161.0
# Skipped vertical alignment, wrong horizontal line with offset 1161.0
# Rotate mask for LIRIBO_0228.jpg
# Loading LIRIBO_0232.jpg
# using only simple binarization.
# using only simple binarization.
# 20.5
# Rotate mask for LIRIBO_0232.jpg
# Loading LIRIBO_0242.jpg
# using only simple binarization.
# using only simple binarization.
# 17.5
# Rotate mask for LIRIBO_0242.jpg
# Loading LIRIBO_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 1191.5
# Skipped vertical alignment, wrong horizontal line with offset 1191.5
# Rotate mask for LIRIBO_0253.jpg
# Loading LIRIBO_0262.jpg
# using only simple binarization.
# using only simple binarization.
# 11.0
# Rotate mask for LIRIBO_0262.jpg
# Loading LIRIBO_0268.jpg
# using only simple binarization.
# using only simple binarization.
# -19.0
# Rotate mask for LIRIBO_0268.jpg
# Loading LIRIBO_0269.jpg
# using only simple binarization.
# using only simple binarization.
# -44.0
# Rotate mask for LIRIBO_0269.jpg
# Loading LIRIBO_0273.jpg
# using only simple binarization.
# using only simple binarization.
# 16.0
# Rotate mask for LIRIBO_0273.jpg
# Loading LIRIBO_0274.jpg
# using only simple binarization.
# using only simple binarization.
# 21.5
# Rotate mask for LIRIBO_0274.jpg
# Loading LIRIBO_0275.jpg
# using only simple binarization.
# using only simple binarization.
# -22.0
# Rotate mask for LIRIBO_0275.jpg
# Loading LIRIBO_0277.jpg
# using only simple binarization.
# using only simple binarization.
# -37.0
# Rotate mask for LIRIBO_0277.jpg
# Loading LIRIBO_0283.jpg
# using only simple binarization.
# using only simple binarization.
# -22.0
# Rotate mask for LIRIBO_0283.jpg
# Loading LIRIBO_0284.jpg
# using only simple binarization.
# using only simple binarization.
# 13.5
# Rotate mask for LIRIBO_0284.jpg
# Loading LIRIBO_0290.jpg
# using only simple binarization.
# No YST found for LIRIBO_0290.jpg
# Loading LIRIBO_0297.jpg
# using only simple binarization.
# using only simple binarization.
# -68.0
# Rotate mask for LIRIBO_0297.jpg
# Loading LIRIBO_0311.jpg
# using only simple binarization.
# using only simple binarization.
# 0.0
# Rotate mask for LIRIBO_0311.jpg
# Loading LIRIBO_0312.jpg
# using only simple binarization.
# using only simple binarization.
# 18.5
# Rotate mask for LIRIBO_0312.jpg
# Loading LIRIBO_0322.jpg
# using only simple binarization.
# using only simple binarization.
# 20.5
# Rotate mask for LIRIBO_0322.jpg
# Loading LIRIBO_0323.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0323.jpg
# Loading LIRIBO_0329.jpg
# using only simple binarization.
# using only simple binarization.
# 1187.5
# Skipped vertical alignment, wrong horizontal line with offset 1187.5
# Rotate mask for LIRIBO_0329.jpg
# Loading LIRIBO_0337.jpg
# using only simple binarization.
# using only simple binarization.
# -29.0
# Rotate mask for LIRIBO_0337.jpg
# Loading LIRIBO_0340.jpg
# using only simple binarization.
# using only simple binarization.
# 1241.5
# Skipped vertical alignment, wrong horizontal line with offset 1241.5
# Rotate mask for LIRIBO_0340.jpg
# Loading LIRIBO_0346.jpg
# using only simple binarization.
# using only simple binarization.
# -27.0
# Rotate mask for LIRIBO_0346.jpg
# Loading LIRIBO_0349.jpg
# using only simple binarization.
# No YST found for LIRIBO_0349.jpg
# Loading LIRIBO_0351.jpg
# using only simple binarization.
# using only simple binarization.
# -29.5
# Rotate mask for LIRIBO_0351.jpg
# Loading LIRIBO_0354.jpg
# using only simple binarization.
# using only simple binarization.
# -30.0
# Rotate mask for LIRIBO_0354.jpg
# Loading LIRIBO_0376.jpg
# using only simple binarization.
# using only simple binarization.
# 99.0
# Rotate mask for LIRIBO_0376.jpg
# Loading LIRIBO_0377.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0377.jpg
# Loading LIRIBO_0380.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for LIRIBO_0380.jpg
# Loading LIRIBO_0397.jpg
# using only simple binarization.
# using only simple binarization.
# 98.5
# Rotate mask for LIRIBO_0397.jpg
# Loading LIRIBO_0401.jpg
# using only simple binarization.
# using only simple binarization.
# 102.5
# Rotate mask for LIRIBO_0401.jpg
# Loading LIRIBO_0413.jpg
# using only simple binarization.
# using only simple binarization.
# -30.0
# Rotate mask for LIRIBO_0413.jpg
# Loading LIRIBO_0416.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0416.jpg
# Loading LIRIBO_0430.jpg
# using only simple binarization.
# using only simple binarization.
# 113.5
# Rotate mask for LIRIBO_0430.jpg
# Loading LIRIBO_0434.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0434.jpg
# Loading LIRIBO_0440.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for LIRIBO_0440.jpg
# Loading LIRIBO_0447.jpg
# using only simple binarization.
# using only simple binarization.
# 82.0
# Rotate mask for LIRIBO_0447.jpg
# Loading LIRIBO_0457.jpg
# using only simple binarization.
# using only simple binarization.
# -17.0
# Rotate mask for LIRIBO_0457.jpg
# Loading LIRIBO_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 73.5
# Rotate mask for LIRIBO_0463.jpg
# Loading LIRIBO_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Rotate mask for LIRIBO_0467.jpg
# Loading LIRIBO_0471.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for LIRIBO_0471.jpg
# Loading LIRIBO_0488.jpg
# using only simple binarization.
# using only simple binarization.
# 64.5
# Rotate mask for LIRIBO_0488.jpg
# Loading LIRIBO_0489.jpg
# using only simple binarization.
# using only simple binarization.
# 68.5
# Rotate mask for LIRIBO_0489.jpg
# Loading LIRIBO_0490.jpg
# using only simple binarization.
# using only simple binarization.
# 85.5
# Rotate mask for LIRIBO_0490.jpg
# Loading LIRIBO_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1195.5
# Skipped vertical alignment, wrong horizontal line with offset 1195.5
# Rotate mask for LIRIBO_0500.jpg
# Loading LIRIBO_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 86.0
# Rotate mask for LIRIBO_0501.jpg
# Loading LIRIBO_0509.jpg
# using only simple binarization.
# using only simple binarization.
# 94.0
# Rotate mask for LIRIBO_0509.jpg
# Loading LIRIBO_0517.jpg
# using only simple binarization.
# using only simple binarization.
# 81.0
# Rotate mask for LIRIBO_0517.jpg
# Loading LIRIBO_0519.jpg
# using only simple binarization.
# using only simple binarization.
# 105.0
# Rotate mask for LIRIBO_0519.jpg
# Loading LIRIBO_0525.jpg
# using only simple binarization.
# using only simple binarization.
# 1220.0
# Skipped vertical alignment, wrong horizontal line with offset 1220.0
# Rotate mask for LIRIBO_0525.jpg
# Loading LIRIBO_0530.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0530.jpg
# Loading LIRIBO_0533.jpg
# using only simple binarization.
# No YST found for LIRIBO_0533.jpg
# Loading LIRIBO_0534.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for LIRIBO_0534.jpg
# Loading LIRIBO_0539.jpg
# using only simple binarization.
# No YST found for LIRIBO_0539.jpg
# Loading LIRIBO_0543.jpg
# using only simple binarization.
# No YST found for LIRIBO_0543.jpg
# Loading LIRIBO_0544.jpg
# using only simple binarization.
# No YST found for LIRIBO_0544.jpg
# Loading LIRIBO_0546.jpg
# using only simple binarization.
# No YST found for LIRIBO_0546.jpg
# Loading LIRIBO_0547.jpg
# using only simple binarization.
# No YST found for LIRIBO_0547.jpg
# Loading LIRIBO_0553.jpg
# using only simple binarization.
# No YST found for LIRIBO_0553.jpg
# Loading LIRIBO_0557.jpg
# using only simple binarization.
# No YST found for LIRIBO_0557.jpg
# Loading LIRIBO_0562.jpg
# using only simple binarization.
# No YST found for LIRIBO_0562.jpg
# Loading LIRIBO_0569.jpg
# using only simple binarization.
# No YST found for LIRIBO_0569.jpg
# Loading LIRIBO_0571.jpg
# using only simple binarization.
# using only simple binarization.
# 104.5
# Rotate mask for LIRIBO_0571.jpg
# Loading LIRIBO_0574.jpg
# using only simple binarization.
# No YST found for LIRIBO_0574.jpg
# Loading LIRIBO_0577.jpg
# using only simple binarization.
# using only simple binarization.
# 120.0
# Rotate mask for LIRIBO_0577.jpg
# Loading LIRIBO_0587.jpg
# using only simple binarization.
# using only simple binarization.
# 108.5
# Rotate mask for LIRIBO_0587.jpg
# Loading LIRIBO_0588.jpg
# using only simple binarization.
# No YST found for LIRIBO_0588.jpg
# Loading LIRIBO_0589.jpg
# using only simple binarization.
# using only simple binarization.
# 100.0
# Rotate mask for LIRIBO_0589.jpg
# Loading LIRIBO_0600.jpg
# using only simple binarization.
# No YST found for LIRIBO_0600.jpg
# Loading LIRIBO_0606.jpg
# using only simple binarization.
# using only simple binarization.
# 112.0
# Rotate mask for LIRIBO_0606.jpg
# Loading LIRIBO_0613.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for LIRIBO_0613.jpg
# Loading LIRIBO_0619.jpg
# using only simple binarization.
# using only simple binarization.
# 99.5
# Rotate mask for LIRIBO_0619.jpg
# Loading LIRIBO_0621.jpg
# using only simple binarization.
# using only simple binarization.
# 100.0
# Rotate mask for LIRIBO_0621.jpg
# Loading LIRIBO_0634.jpg
# using only simple binarization.
# using only simple binarization.
# 1207.0
# Skipped vertical alignment, wrong horizontal line with offset 1207.0
# Rotate mask for LIRIBO_0634.jpg
# Loading LIRIBO_0635.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for LIRIBO_0635.jpg
# Loading LIRIBO_0638.jpg
# using only simple binarization.
# using only simple binarization.
# 100.5
# Rotate mask for LIRIBO_0638.jpg
# Loading LIRIBO_0640.jpg
# using only simple binarization.
# using only simple binarization.
# 88.5
# Rotate mask for LIRIBO_0640.jpg
# Loading LIRIBO_0643.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for LIRIBO_0643.jpg
# Loading LIRIBO_0649.jpg
# using only simple binarization.
# using only simple binarization.
# 78.0
# Rotate mask for LIRIBO_0649.jpg
# Loading LIRIBO_0654.jpg
# using only simple binarization.
# using only simple binarization.
# 79.5
# Rotate mask for LIRIBO_0654.jpg
# Loading LIRIBO_0658.jpg
# using only simple binarization.
# using only simple binarization.
# 84.5
# Rotate mask for LIRIBO_0658.jpg
# Loading LIRIBO_0659.jpg
# using only simple binarization.
# using only simple binarization.
# 89.0
# Rotate mask for LIRIBO_0659.jpg
# Loading LIRIBO_0669.jpg
# using only simple binarization.
# using only simple binarization.
# 109.5
# Rotate mask for LIRIBO_0669.jpg
# Loading LIRIBO_0673.jpg
# using only simple binarization.
# using only simple binarization.
# 107.0
# Rotate mask for LIRIBO_0673.jpg
# Loading TRIAVA_0007.jpg
# using only simple binarization.
# using only simple binarization.
# 2.5
# Rotate mask for TRIAVA_0007.jpg
# Loading TRIAVA_0019.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Loading TRIAVA_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 62.5
# Rotate mask for TRIAVA_0028.jpg
# Loading TRIAVA_0140.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for TRIAVA_0140.jpg
# Loading TRIAVA_0180.jpg
# using only simple binarization.
# using only simple binarization.
# 22.0
# Rotate mask for TRIAVA_0180.jpg
# Loading TRIAVA_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 31.0
# Rotate mask for TRIAVA_0184.jpg
# Loading TRIAVA_0185.jpg
# using only simple binarization.
# using only simple binarization.
# 16.5
# Rotate mask for TRIAVA_0185.jpg
# Loading TRIAVA_0187.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for TRIAVA_0187.jpg
# Loading TRIAVA_0188.jpg
# using only simple binarization.
# using only simple binarization.
# 19.0
# Rotate mask for TRIAVA_0188.jpg
# Loading TRIAVA_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 69.0
# Rotate mask for TRIAVA_0223.jpg
# Loading TRIAVA_0237.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for TRIAVA_0237.jpg
# Loading TRIAVA_0243.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for TRIAVA_0243.jpg
# Loading TRIAVA_0249.jpg
# using only simple binarization.
# using only simple binarization.
# 110.0
# Rotate mask for TRIAVA_0249.jpg
# Loading TRIAVA_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 110.5
# Rotate mask for TRIAVA_0253.jpg
# Loading TRIAVA_0269.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for TRIAVA_0269.jpg
# Loading TRIAVA_0276.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for TRIAVA_0276.jpg
# Loading TRIAVA_0302.jpg
# using only simple binarization.
# No YST found for TRIAVA_0302.jpg
# Loading TRIAVA_0304.jpg
# using only simple binarization.
# No YST found for TRIAVA_0304.jpg
# Loading TRIAVA_0318.jpg
# using only simple binarization.
# using only simple binarization.
# 103.0
# Rotate mask for TRIAVA_0318.jpg
# Loading TRIAVA_0324.jpg
# using only simple binarization.
# using only simple binarization.
# 119.5
# Rotate mask for TRIAVA_0324.jpg
# Loading TRIAVA_0325.jpg
# using only simple binarization.
# using only simple binarization.
# 111.0
# Rotate mask for TRIAVA_0325.jpg
# Loading TRIAVA_0335.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for TRIAVA_0335.jpg
# Loading TRIAVA_0354.jpg
# using only simple binarization.
# using only simple binarization.
# 14.5
# Rotate mask for TRIAVA_0354.jpg
# Loading TRIAVA_0357.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for TRIAVA_0357.jpg
# Loading TRIAVA_0358.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.0
# Skipped vertical alignment, wrong horizontal line with offset 1163.0
# Rotate mask for TRIAVA_0358.jpg
# Loading TRIAVA_0371.jpg
# using only simple binarization.
# using only simple binarization.
# 21.0
# Rotate mask for TRIAVA_0371.jpg
# Loading TRIAVA_0379.jpg
# using only simple binarization.
# using only simple binarization.
# -9.0
# Rotate mask for TRIAVA_0379.jpg
# Loading TRIAVA_0389.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for TRIAVA_0389.jpg
# Loading TRIAVA_0456.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for TRIAVA_0456.jpg
# Loading TRIAVA_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 1250.5
# Skipped vertical alignment, wrong horizontal line with offset 1250.5
# Rotate mask for TRIAVA_0463.jpg
# Loading TRIAVA_0465.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for TRIAVA_0465.jpg
# Loading TRIAVA_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 1225.5
# Skipped vertical alignment, wrong horizontal line with offset 1225.5
# Rotate mask for TRIAVA_0467.jpg
# Loading TRIAVA_0485.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for TRIAVA_0485.jpg
# Loading TRIAVA_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1197.5
# Skipped vertical alignment, wrong horizontal line with offset 1197.5
# Rotate mask for TRIAVA_0500.jpg
# Loading TRIAVA_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 1189.0
# Skipped vertical alignment, wrong horizontal line with offset 1189.0
# Rotate mask for TRIAVA_0501.jpg
# Loading TRIAVA_0504.jpg
# using only simple binarization.
# using only simple binarization.
# -24.0
# Rotate mask for TRIAVA_0504.jpg
# Loading TRIAVA_0590.jpg
# using only simple binarization.
# using only simple binarization.
# 75.0
# Rotate mask for TRIAVA_0590.jpg
# Loading TRIAVA_0591.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for TRIAVA_0591.jpg
# Loading TRIAVA_0626.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for TRIAVA_0626.jpg
# Loading TRIAVA_0628.jpg
# using only simple binarization.
# using only simple binarization.
# -15.5
# Rotate mask for TRIAVA_0628.jpg
#
# Class: BRAIIM
#   True:      18
#   False:     245
#   Unchecked: 41
#
# Class: LIRIBO
#   True:      29
#   False:     176
#   Unchecked: 20
#
# Class: TRIAVA
#   True:      9
#   False:     50
#   Unchecked: 1
#
# Overall totals:
#   True:      56
#   False:     471
#   Unchecked: 62

# %%
stats
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'BRAIIM': {'true': 18, 'false': 245, 'unchecked': 41},
#              'LIRIBO': {'true': 29, 'false': 176, 'unchecked': 20},
#              'TRIAVA': {'true': 9, 'false': 50, 'unchecked': 1}})

# %%
def add_row_fp(df, row_name, mask_value):
    base = df.loc[row_name].copy()

    # Recalculate derived metrics
    tp, fp, fn = base['TP'], base['FP']-mask_value, base['FN']
    precision = tp / (tp + fp) if tp + fp > 0 else 0

    recall = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    print(recall)

    # Create new row
    new_row = base.copy()
    print(new_row)
    new_row["FP"] = fp
    new_row['precision'] = precision
    new_row['recall'] = recall
    new_row['f1'] = f1
    return new_row

#subtract the false negatives correlated to masking
df.loc["summary_fp_masked"] = add_row_fp(df, "summary_fn_masked", 18+29+9)
df.loc["0_fp_masked"] = add_row_fp(df, "0_fn_masked", 18)
df.loc["1_fp_masked"] = add_row_fp(df, "1_fn_masked", 29)
df.loc["3_fp_masked"] = add_row_fp(df, "3_fn_masked", 9)
df
# Out:
# 0.6868415153553015
# TP           3064.000000
# FP            589.000000
# FN           1397.000000
# precision       0.838763
# recall          0.686842
# f1              0.755238
# Name: summary_fn_masked, dtype: float64
# 0.8084648493543759
# TP           1127.000000
# FP            321.000000
# FN            267.000000
# precision       0.778315
# recall          0.808465
# f1              0.793103
# Name: 0_fn_masked, dtype: float64
# 0.8752166377816292
# TP           1010.000000
# FP            179.000000
# FN            144.000000
# precision       0.849453
# recall          0.875217
# f1              0.862143
# Name: 1_fn_masked, dtype: float64
# 0.48457919498170415
# TP           927.000000
# FP            89.000000
# FN           986.000000
# precision      0.912402
# recall         0.484579
# f1             0.632981
# Name: 3_fn_masked, dtype: float64
#                        TP     FP      FN  precision    recall        f1
# summary            3064.0  589.0  2396.0   0.838763  0.561172  0.672446
# 0                  1127.0  321.0   452.0   0.778315  0.713743  0.744632
# 1                  1010.0  179.0   249.0   0.849453  0.802224  0.825163
# 3                   927.0   89.0  1695.0   0.912402  0.353547  0.509621
# summary_fn_masked  3064.0  589.0  1397.0   0.838763  0.686842  0.755238
# 0_fn_masked        1127.0  321.0   267.0   0.778315  0.808465  0.793103
# 1_fn_masked        1010.0  179.0   144.0   0.849453  0.875217  0.862143
# 3_fn_masked         927.0   89.0   986.0   0.912402  0.484579  0.632981
# summary_fp_masked  3064.0  533.0  1397.0   0.851821  0.686842  0.760486
# 0_fp_masked        1127.0  303.0   267.0   0.788112  0.808465  0.798159
# 1_fp_masked        1010.0  150.0   144.0   0.870690  0.875217  0.872947
# 3_fp_masked         927.0   80.0   986.0   0.920556  0.484579  0.634932

# %%
def mean_hsv_otsu(box, img):
    x1, y1, x2, y2 = map(int, box)
    roi = img[y1:y2, x1:x2]
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    v_channel = hsv[:, :, 2]

    # Apply Otsu's threshold on V
    _, mask = cv2.threshold(v_channel, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Convert mask to boolean for indexing
    mask_bool = mask == 255

    s_pixels = hsv[:, :, 1][mask_bool]
    v_pixels = hsv[:, :, 2][mask_bool]

    if s_pixels.size == 0 or v_pixels.size == 0:
        return (np.nan, np.nan)

    mean_s = float(np.mean(s_pixels))
    mean_v = float(np.mean(v_pixels))

    return (mean_s, mean_v)


def mean_hsv_box(box, img):
    x1, y1, x2, y2 = map(int, box)
    roi = img[y1:y2, x1:x2]
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)
    return hsv[:, :, 1].mean(), hsv[:, :, 2].mean()  # (S, V)

# %%
tp_s_means = []
tp_v_means = []
fn_s_means = []
fn_v_means = []

for i in range(len(data)):
    f = data[i]["filename"]
    if not f.startswith("TRIAVA"):
        continue

    fn = data[i]["false_negatives"]["boxes"]
    tp = data[i]["true_positives"]["boxes"]

    mask = get_mask(f)
    if mask is None:
        print(f"No mask detectable for {f}.")
        continue

    if f in files_rotated:
        print(f"Rotate mask for {f}")
        mask = cv2.rotate(mask, cv2.ROTATE_180)

    overlaps = compute_mask_coverage(mask, fn, threshold=0.2)
    filtered_fn = [box for i, box in enumerate(fn) if not overlaps[i][2]]

    img = cv2.imread(os.path.join(
        "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/images", f
    ))

    fn_sv = [mean_hsv_box(box, img) for box in filtered_fn]
    tp_sv = [mean_hsv_box(box, img) for box in tp]

    if fn_sv:  # only if not empty
        fn_s, fn_v = zip(*fn_sv)
        fn_s_means.extend(fn_s)
        fn_v_means.extend(fn_v)

    if tp_sv:
        tp_s, tp_v = zip(*tp_sv)
        tp_s_means.extend(tp_s)
        tp_v_means.extend(tp_v)


        



'''

for box in fn:
    x1,y1,x2,y2 = map(int, box)
    cv2.rectangle(img, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=2)
for box in tp:
    x1,y1,x2,y2 = map(int, box)
    cv2.rectangle(img, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=2)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()
                
'''
# Out:
# Loading TRIAVA_0007.jpg
# using only simple binarization.
# using only simple binarization.
# 2.5
# Rotate mask for TRIAVA_0007.jpg
# Loading TRIAVA_0019.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Loading TRIAVA_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 62.5
# Rotate mask for TRIAVA_0028.jpg
# Loading TRIAVA_0140.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for TRIAVA_0140.jpg
# Loading TRIAVA_0180.jpg
# using only simple binarization.
# using only simple binarization.
# 22.0
# Rotate mask for TRIAVA_0180.jpg
# Loading TRIAVA_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 31.0
# Rotate mask for TRIAVA_0184.jpg
# Loading TRIAVA_0185.jpg
# using only simple binarization.
# using only simple binarization.
# 16.5
# Rotate mask for TRIAVA_0185.jpg
# Loading TRIAVA_0187.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for TRIAVA_0187.jpg
# Loading TRIAVA_0188.jpg
# using only simple binarization.
# using only simple binarization.
# 19.0
# Rotate mask for TRIAVA_0188.jpg
# Loading TRIAVA_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 69.0
# Rotate mask for TRIAVA_0223.jpg
# Loading TRIAVA_0237.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for TRIAVA_0237.jpg
# Loading TRIAVA_0243.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for TRIAVA_0243.jpg
# Loading TRIAVA_0249.jpg
# using only simple binarization.
# using only simple binarization.
# 110.0
# Rotate mask for TRIAVA_0249.jpg
# Loading TRIAVA_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 110.5
# Rotate mask for TRIAVA_0253.jpg
# Loading TRIAVA_0269.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for TRIAVA_0269.jpg
# Loading TRIAVA_0276.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for TRIAVA_0276.jpg
# Loading TRIAVA_0302.jpg
# using only simple binarization.
# No YST found for TRIAVA_0302.jpg
# No mask detectable for TRIAVA_0302.jpg.
# Loading TRIAVA_0304.jpg
# using only simple binarization.
# No YST found for TRIAVA_0304.jpg
# No mask detectable for TRIAVA_0304.jpg.
# Loading TRIAVA_0318.jpg
# using only simple binarization.
# using only simple binarization.
# 103.0
# Rotate mask for TRIAVA_0318.jpg
# Loading TRIAVA_0324.jpg
# using only simple binarization.
# using only simple binarization.
# 119.5
# Rotate mask for TRIAVA_0324.jpg
# Loading TRIAVA_0325.jpg
# using only simple binarization.
# using only simple binarization.
# 111.0
# Rotate mask for TRIAVA_0325.jpg
# Loading TRIAVA_0335.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for TRIAVA_0335.jpg
# Loading TRIAVA_0354.jpg
# using only simple binarization.
# using only simple binarization.
# 14.5
# Rotate mask for TRIAVA_0354.jpg
# Loading TRIAVA_0357.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for TRIAVA_0357.jpg
# Loading TRIAVA_0358.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.0
# Skipped vertical alignment, wrong horizontal line with offset 1163.0
# Rotate mask for TRIAVA_0358.jpg
# Loading TRIAVA_0371.jpg
# using only simple binarization.
# using only simple binarization.
# 21.0
# Rotate mask for TRIAVA_0371.jpg
# Loading TRIAVA_0379.jpg
# using only simple binarization.
# using only simple binarization.
# -9.0
# Rotate mask for TRIAVA_0379.jpg
# Loading TRIAVA_0389.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for TRIAVA_0389.jpg
# Loading TRIAVA_0456.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for TRIAVA_0456.jpg
# Loading TRIAVA_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 1250.5
# Skipped vertical alignment, wrong horizontal line with offset 1250.5
# Rotate mask for TRIAVA_0463.jpg
# Loading TRIAVA_0465.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for TRIAVA_0465.jpg
# Loading TRIAVA_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 1225.5
# Skipped vertical alignment, wrong horizontal line with offset 1225.5
# Rotate mask for TRIAVA_0467.jpg
# Loading TRIAVA_0485.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for TRIAVA_0485.jpg
# Loading TRIAVA_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1197.5
# Skipped vertical alignment, wrong horizontal line with offset 1197.5
# Rotate mask for TRIAVA_0500.jpg
# Loading TRIAVA_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 1189.0
# Skipped vertical alignment, wrong horizontal line with offset 1189.0
# Rotate mask for TRIAVA_0501.jpg
# Loading TRIAVA_0504.jpg
# using only simple binarization.
# using only simple binarization.
# -24.0
# Rotate mask for TRIAVA_0504.jpg
# Loading TRIAVA_0590.jpg
# using only simple binarization.
# using only simple binarization.
# 75.0
# Rotate mask for TRIAVA_0590.jpg
# Loading TRIAVA_0591.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for TRIAVA_0591.jpg
# Loading TRIAVA_0626.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for TRIAVA_0626.jpg
# Loading TRIAVA_0628.jpg
# using only simple binarization.
# using only simple binarization.
# -15.5
# Rotate mask for TRIAVA_0628.jpg
# '\n\nfor box in fn:\n    x1,y1,x2,y2 = map(int, box)\n    cv2.rectangle(img, (x1, y1), (x2,y2), color=(0, 255, 0), thickness=2)\nfor box in tp:\n    x1,y1,x2,y2 = map(int, box)\n    cv2.rectangle(img, (x1, y1), (x2,y2), color=(0, 0, 255), thickness=2)\nimg_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)\nplt.imshow(img_rgb)\nplt.axis("off")\nplt.show()\n\n'

# %%
print("Mean Saturation (FN):", np.mean(fn_s_means))
print("Mean Value (FN):", np.mean(fn_v_means))
print("Mean Saturation (TP):", np.mean(tp_s_means))
print("Mean Value (TP):", np.mean(tp_v_means))
# Out:
# Mean Saturation (FN): 200.17060234878147
# Mean Value (FN): 155.40734896270502
# Mean Saturation (TP): 175.05194383104947
# Mean Value (TP): 158.04063827992272

# %%
import matplotlib.pyplot as plt

plt.boxplot([fn_v_means, tp_v_means], labels=["FN", "TP"])
plt.ylabel("Mean V (Brightness)")
plt.title("Brightness comparison between FN and TP")
plt.show() 

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))

bins = np.linspace(
    min(np.nanmin(fn_v_means), np.nanmin(tp_v_means)),
    max(np.nanmax(fn_v_means), np.nanmax(tp_v_means)),
    30
)

plt.hist(fn_v_means, bins=bins, alpha=0.6, label="FN", color="red")
plt.hist(tp_v_means, bins=bins, alpha=0.6, label="TP", color="blue")

plt.xlabel("Mean Value (Brightness, V)")
plt.ylabel("Count")
plt.title("Histogram of Brightness (V) — FN vs TP")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /mnt/lustre-grete/tmp/u15287/ipykernel_2505004/3361097888.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([fn_v_means, tp_v_means], labels=["FN", "TP"])

# %%
tp_s_means = []
tp_v_means = []
fn_s_means = []
fn_v_means = []

for i in range(len(data)):
    f = data[i]["filename"]
    if not f.startswith("TRIAVA"):
        continue

    fn = data[i]["false_negatives"]["boxes"]
    tp = data[i]["true_positives"]["boxes"]

    mask = get_mask(f)
    if mask is None:
        print(f"No mask detectable for {f}.")
        continue

    if f in files_rotated:
        print(f"Rotate mask for {f}")
        mask = cv2.rotate(mask, cv2.ROTATE_180)

    overlaps = compute_mask_coverage(mask, fn, threshold=0.2)
    filtered_fn = [box for i, box in enumerate(fn) if not overlaps[i][2]]

    img = cv2.imread(os.path.join(
        "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/images", f
    ))

    fn_sv = [mean_hsv_otsu(box, img) for box in filtered_fn]
    tp_sv = [mean_hsv_otsu(box, img) for box in tp]

    if fn_sv:  # only if not empty
        fn_s, fn_v = zip(*fn_sv)
        fn_s_means.extend(fn_s)
        fn_v_means.extend(fn_v)

    if tp_sv:
        tp_s, tp_v = zip(*tp_sv)
        tp_s_means.extend(tp_s)
        tp_v_means.extend(tp_v)
# Out:
# Loading TRIAVA_0007.jpg
# using only simple binarization.
# using only simple binarization.
# 2.5
# Rotate mask for TRIAVA_0007.jpg
# Loading TRIAVA_0019.jpg
# using only simple binarization.
# using only simple binarization.
# 65.0
# Loading TRIAVA_0028.jpg
# using only simple binarization.
# using only simple binarization.
# 62.5
# Rotate mask for TRIAVA_0028.jpg
# Loading TRIAVA_0140.jpg
# using only simple binarization.
# using only simple binarization.
# 54.5
# Rotate mask for TRIAVA_0140.jpg
# Loading TRIAVA_0180.jpg
# using only simple binarization.
# using only simple binarization.
# 22.0
# Rotate mask for TRIAVA_0180.jpg
# Loading TRIAVA_0184.jpg
# using only simple binarization.
# using only simple binarization.
# 31.0
# Rotate mask for TRIAVA_0184.jpg
# Loading TRIAVA_0185.jpg
# using only simple binarization.
# using only simple binarization.
# 16.5
# Rotate mask for TRIAVA_0185.jpg
# Loading TRIAVA_0187.jpg
# using only simple binarization.
# using only simple binarization.
# 45.0
# Rotate mask for TRIAVA_0187.jpg
# Loading TRIAVA_0188.jpg
# using only simple binarization.
# using only simple binarization.
# 19.0
# Rotate mask for TRIAVA_0188.jpg
# Loading TRIAVA_0223.jpg
# using only simple binarization.
# using only simple binarization.
# 69.0
# Rotate mask for TRIAVA_0223.jpg
# Loading TRIAVA_0237.jpg
# using only simple binarization.
# using only simple binarization.
# 68.0
# Rotate mask for TRIAVA_0237.jpg
# Loading TRIAVA_0243.jpg
# using only simple binarization.
# using only simple binarization.
# 101.0
# Rotate mask for TRIAVA_0243.jpg
# Loading TRIAVA_0249.jpg
# using only simple binarization.
# using only simple binarization.
# 110.0
# Rotate mask for TRIAVA_0249.jpg
# Loading TRIAVA_0253.jpg
# using only simple binarization.
# using only simple binarization.
# 110.5
# Rotate mask for TRIAVA_0253.jpg
# Loading TRIAVA_0269.jpg
# using only simple binarization.
# using only simple binarization.
# 90.0
# Rotate mask for TRIAVA_0269.jpg
# Loading TRIAVA_0276.jpg
# using only simple binarization.
# using only simple binarization.
# 80.0
# Rotate mask for TRIAVA_0276.jpg
# Loading TRIAVA_0302.jpg
# using only simple binarization.
# No YST found for TRIAVA_0302.jpg
# No mask detectable for TRIAVA_0302.jpg.
# Loading TRIAVA_0304.jpg
# using only simple binarization.
# No YST found for TRIAVA_0304.jpg
# No mask detectable for TRIAVA_0304.jpg.
# Loading TRIAVA_0318.jpg
# using only simple binarization.
# using only simple binarization.
# 103.0
# Rotate mask for TRIAVA_0318.jpg
# Loading TRIAVA_0324.jpg
# using only simple binarization.
# using only simple binarization.
# 119.5
# Rotate mask for TRIAVA_0324.jpg
# Loading TRIAVA_0325.jpg
# using only simple binarization.
# using only simple binarization.
# 111.0
# Rotate mask for TRIAVA_0325.jpg
# Loading TRIAVA_0335.jpg
# using only simple binarization.
# using only simple binarization.
# 117.5
# Rotate mask for TRIAVA_0335.jpg
# Loading TRIAVA_0354.jpg
# using only simple binarization.
# using only simple binarization.
# 14.5
# Rotate mask for TRIAVA_0354.jpg
# Loading TRIAVA_0357.jpg
# using only simple binarization.
# using only simple binarization.
# 15.0
# Rotate mask for TRIAVA_0357.jpg
# Loading TRIAVA_0358.jpg
# using only simple binarization.
# using only simple binarization.
# 1163.0
# Skipped vertical alignment, wrong horizontal line with offset 1163.0
# Rotate mask for TRIAVA_0358.jpg
# Loading TRIAVA_0371.jpg
# using only simple binarization.
# using only simple binarization.
# 21.0
# Rotate mask for TRIAVA_0371.jpg
# Loading TRIAVA_0379.jpg
# using only simple binarization.
# using only simple binarization.
# -9.0
# Rotate mask for TRIAVA_0379.jpg
# Loading TRIAVA_0389.jpg
# using only simple binarization.
# using only simple binarization.
# -8.0
# Rotate mask for TRIAVA_0389.jpg
# Loading TRIAVA_0456.jpg
# using only simple binarization.
# using only simple binarization.
# 107.5
# Rotate mask for TRIAVA_0456.jpg
# Loading TRIAVA_0463.jpg
# using only simple binarization.
# using only simple binarization.
# 1250.5
# Skipped vertical alignment, wrong horizontal line with offset 1250.5
# Rotate mask for TRIAVA_0463.jpg
# Loading TRIAVA_0465.jpg
# using only simple binarization.
# using only simple binarization.
# 106.0
# Rotate mask for TRIAVA_0465.jpg
# Loading TRIAVA_0467.jpg
# using only simple binarization.
# using only simple binarization.
# 1225.5
# Skipped vertical alignment, wrong horizontal line with offset 1225.5
# Rotate mask for TRIAVA_0467.jpg
# Loading TRIAVA_0485.jpg
# using only simple binarization.
# using only simple binarization.
# 117.0
# Rotate mask for TRIAVA_0485.jpg
# Loading TRIAVA_0500.jpg
# using only simple binarization.
# using only simple binarization.
# 1197.5
# Skipped vertical alignment, wrong horizontal line with offset 1197.5
# Rotate mask for TRIAVA_0500.jpg
# Loading TRIAVA_0501.jpg
# using only simple binarization.
# using only simple binarization.
# 1189.0
# Skipped vertical alignment, wrong horizontal line with offset 1189.0
# Rotate mask for TRIAVA_0501.jpg
# Loading TRIAVA_0504.jpg
# using only simple binarization.
# using only simple binarization.
# -24.0
# Rotate mask for TRIAVA_0504.jpg
# Loading TRIAVA_0590.jpg
# using only simple binarization.
# using only simple binarization.
# 75.0
# Rotate mask for TRIAVA_0590.jpg
# Loading TRIAVA_0591.jpg
# using only simple binarization.
# using only simple binarization.
# 84.0
# Rotate mask for TRIAVA_0591.jpg
# Loading TRIAVA_0626.jpg
# using only simple binarization.
# using only simple binarization.
# -26.0
# Rotate mask for TRIAVA_0626.jpg
# Loading TRIAVA_0628.jpg
# using only simple binarization.
# using only simple binarization.
# -15.5
# Rotate mask for TRIAVA_0628.jpg

# %%
print("Mean Saturation (FN):", np.mean(fn_s_means))
print("Mean Value (FN):", np.mean(fn_v_means))
print("Mean Saturation (TP):", np.mean(tp_s_means))
print("Mean Value (TP):", np.mean(tp_v_means))
# Out:
# Mean Saturation (FN): 203.09255896234328
# Mean Value (FN): 160.38302054860162
# Mean Saturation (TP): 169.32488307077892
# Mean Value (TP): 164.67188689832398

# %%
import matplotlib.pyplot as plt

plt.boxplot([fn_v_means, tp_v_means], labels=["FN", "TP"])
plt.ylabel("Mean V (Brightness)")
plt.title("Brightness comparison between FN and TP")
plt.show() 

import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8,5))

bins = np.linspace(
    min(np.nanmin(fn_v_means), np.nanmin(tp_v_means)),
    max(np.nanmax(fn_v_means), np.nanmax(tp_v_means)),
    30
)

plt.hist(fn_v_means, bins=bins, alpha=0.6, label="FN", color="red")
plt.hist(tp_v_means, bins=bins, alpha=0.6, label="TP", color="blue")

plt.xlabel("Mean Value (Brightness, V)")
plt.ylabel("Count")
plt.title("Histogram of Brightness (V) — FN vs TP")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /mnt/lustre-grete/tmp/u15287/ipykernel_2505004/3361097888.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([fn_v_means, tp_v_means], labels=["FN", "TP"])
