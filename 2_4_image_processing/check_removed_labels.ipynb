# %%
import sys
sys.path.append("/user/christoph.wald/u15287/insect_pest_detection/modules")
from modules_segmentation import draw_boxes_on_images

# %%
image_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/04_images_cropped"
label_folder = "/user/christoph.wald/u15287/big-scratch/02_splitted_data/test_set/SSL/04_labels_cropped_and_filtered"
output_folder = "/user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/check_removed_labels"
draw_boxes_on_images(image_folder, label_folder, output_folder)
# Out:
# Saved: /user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/check_removed_labels/LIRIBO_0273.jpg
# Saved: /user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/check_removed_labels/TRIAVA_0626.jpg
# Saved: /user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/check_removed_labels/TRIAVA_0184.jpg
# Saved: /user/christoph.wald/u15287/insect_pest_detection/2_4_image_processing/check_removed_labels/TRIAVA_0237.jpg
